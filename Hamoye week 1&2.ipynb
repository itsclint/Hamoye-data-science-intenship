# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os

# %%
ls
# Out:
# Untitled.ipynb  fuel_ferc1.csv

# %%
data = 'fuel_ferc1.csv'
df = pd.read_csv(data)
df.head(50)
# Out:
#                  record_id  utility_id_ferc1  report_year  \
# 0    f1_fuel_1994_12_1_0_7                 1         1994
# 1   f1_fuel_1994_12_1_0_10                 1         1994
# 2    f1_fuel_1994_12_2_0_1                 2         1994
# 3    f1_fuel_1994_12_2_0_7                 2         1994
# 4   f1_fuel_1994_12_2_0_10                 2         1994
# 5   f1_fuel_1994_12_2_0_13                 2         1994
# 6    f1_fuel_1994_12_2_1_1                 2         1994
# 7   f1_fuel_1994_12_2_1_10                 2         1994
# 8   f1_fuel_1994_12_2_2_10                 2         1994
# 9    f1_fuel_1994_12_4_0_1                 4         1994
# 10   f1_fuel_1994_12_4_0_2                 4         1994
# 11   f1_fuel_1994_12_4_0_4                 4         1994
# 12   f1_fuel_1994_12_4_0_5                 4         1994
# 13   f1_fuel_1994_12_6_0_1                 6         1994
# 14   f1_fuel_1994_12_6_0_2                 6         1994
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
df.tail(50)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 29473  f1_fuel_2018_12_193_0_13               193         2018
# 29474  f1_fuel_2018_12_193_0_15               193         2018
# 29475   f1_fuel_2018_12_193_1_1               193         2018
# 29476   f1_fuel_2018_12_193_1_5               193         2018
# 29477   f1_fuel_2018_12_193_1_7               193         2018
# 29478   f1_fuel_2018_12_193_1_9               193         2018
# 29479  f1_fuel_2018_12_193_1_10               193         2018
# 29480  f1_fuel_2018_12_193_1_12               193         2018
# 29481  f1_fuel_2018_12_193_1_15               193         2018
# 29482    f1_fuel_2018_12_80_0_2                80         2018
# 29483    f1_fuel_2018_12_80_0_5                80         2018
# 29484    f1_fuel_2018_12_80_0_6                80         2018
# 29485    f1_fuel_2018_12_80_0_8                80         2018
# 29486    f1_fuel_2018_12_80_0_9                80         2018
# ...

# %%
df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
df.groupby('report_year')['fuel_cost_per_unit_delivered'].mean()
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
df.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
df.isna().mean().round(4) * 100
# Out:
# record_id                       0.00
# utility_id_ferc1                0.00
# report_year                     0.00
# plant_name_ferc1                0.00
# fuel_type_code_pudl             0.00
# fuel_unit                       0.61
# fuel_qty_burned                 0.00
# fuel_mmbtu_per_unit             0.00
# fuel_cost_per_unit_burned       0.00
# fuel_cost_per_unit_delivered    0.00
# fuel_cost_per_mmbtu             0.00
# dtype: float64

# %%
df.groupby(['fuel_type_code_pudl', 'report_year'])['fuel_cost_per_unit_burned'].round() * 100
# Out:
# fuel_type_code_pudl  report_year
# coal                 1994            3154.646737
#                      1995            3067.744211
#                      1996            2945.429930
#                      1997           10489.730935
#                      1998            2761.623434
#                                         ...
# waste                2014            3286.633333
#                      2015            3495.944444
#                      2016            3171.052941
#                      2017            3013.860000
#                      2018            4131.075000
# Name: fuel_cost_per_unit_burned, Length: 148, dtype: float64

# %%
df.skew()
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
df.kurtosis()
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %%
df['fuel_type_code_pudl'].unique()
# Out:
# array(['coal', 'gas', 'nuclear', 'oil', 'waste', 'other'], dtype=object)

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.countplot(df['fuel_type_code_pudl'])

# %%
df['plant_name_ferc1'].unique
# Out:
# <bound method Series.unique of 0                    rockport
# 1        rockport total plant
# 2                      gorgas
# 3                       barry
# 4                   chickasaw
#                  ...
# 29518      neil simpson ct #1
# 29519    cheyenne prairie 58%
# 29520       lange ct facility
# 29521         wygen 3 bhp 52%
# 29522         wygen 3 bhp 52%
# Name: plant_name_ferc1, Length: 29523, dtype: object>

# %%
sns.set()
sns.countplot(df['plant_name_ferc1'])

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.relplot(x='report_year', y='fuel_qty_burned', hue='fuel_type_code_pudl',
            height=9, aspect=1.2,linewidth=3.5, kind='line', estimator=None, data=df)

# %%
sns.relplot(x='report_year', y='fuel_mmbtu_per_unit', hue='fuel_type_code_pudl',
            height=9, aspect=1.2,linewidth=3.5, kind='line', estimator=None, data=df)

# %%
sns.relplot(x='report_year', y='fuel_mmbtu_per_unit',
            col='fuel_type_code_pudl', col_wrap=3,
            height=5, aspect=.75,linewidth=3.5, kind='line',
            data=df)

# %%
df.hist(bins=50, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a27375610>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(20,10))
c= df[].corr()
sns.heatmap(c,cmap='BrBG',annot=True)
c
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
sns.regplot(x='report_year', y='fuel_cost_per_mmbtu', data=df)

# %%
sns.relplot(x='report_year', y='fuel_cost_per_mmbtu',
            height=9, aspect=1.2,linewidth=3.5, kind='line', estimator=None, data=df)

# %%
sns.relplot(x='report_year', y='fuel_cost_per_mmbtu', hue='fuel_type_code_pudl',
            height=9, aspect=1.2,linewidth=3.5, kind='line', estimator=None, data=df)

# %%
g = sns.PairGrid(data=df, hue="fuel_type_code_pudl")
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend();

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
A = [1,2,3,4,5,6]
B = [13,21,34]
A.extend(B)
A_B = print(A)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
df.groupby('report_year')['fuel_cost_per_unit_burned'].mean().pct_change()
# Out:
# report_year
# 1994         NaN
# 1995    0.662457
# 1996   -0.775875
# 1997    0.881817
# 1998   -0.152517
# 1999   -0.052334
# 2000    0.980758
# 2001   -0.440645
# 2002   -0.239327
# 2003    0.217481
# 2004    0.257448
# 2005   -0.308502
# 2006    0.413122
# 2007    0.338666
# 2008    0.263211
# 2009   -0.157274
# 2010    0.219064
# 2011    0.147569
# 2012   -0.142335
# 2013   -0.010870
# 2014    0.728026
# 2015   -0.462127
# 2016    0.038459
# 2017   -0.003247
# 2018   -0.053962
# Name: fuel_cost_per_unit_burned, dtype: float64
